# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
from tqdm import tqdm
from glob import glob
from tqdm import tqdm
import seaborn as sns
# %matplotlib inline
import train_util
import util
# %load_ext autoreload
# %autoreload 2
import keras
from keras.layers import Input, Dense, Flatten, Dropout
from keras.models import Model, Sequential
from keras.utils import np_utils

from keras.models import load_model
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
X, X_feat, Y, Y_no_sult = train_util.get_data(size=(221, 221, 3))
# Out:
# 100%|██████████| 3887/3887 [00:56<00:00, 68.31it/s]

# %%
input_tensor = Input(shape=(221, 221, 3))
dense_model = keras.applications.densenet.DenseNet121(include_top=False, weights='imagenet', input_tensor=input_tensor, pooling=None)

# %%
# add FC layer
top_model = Sequential()
top_model.add(Flatten(input_shape=dense_model.output_shape[1:]))
top_model.add(Dropout(0.5))
top_model.add(Dense(512, activation='relu'))
top_model.add(Dropout(0.5))
top_model.add(Dense(2, activation='sigmoid'))
model = Model(input=dense_model.input, output=top_model(dense_model.output))
# Out:
# /root/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:8: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("se...)`

# %%
from sklearn.cross_validation import train_test_split
x_train, x_test, x_feat_train, x_feat_test, y_train, y_test = train_test_split(X, X_feat, Y_no_sult, test_size=0.1, random_state=43)
y_train = np_utils.to_categorical(y_train, 2)
y_test = np_utils.to_categorical(y_test, 2)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-5-bc682edb904d> in <module>()
#       1 from sklearn.cross_validation import train_test_split
#       2 x_train, x_test, x_feat_train, x_feat_test, y_train, y_test = train_test_split(X, X_feat, Y_no_sult, test_size=0.1, random_state=43)
# ----> 3 y_train = np_utils.to_categorical(y_train, 2)
#       4 y_test = np_utils.to_categorical(y_test, 2)
#
# NameError: name 'np_utils' is not defined

# %%
from keras.preprocessing.image import ImageDataGenerator
data_gen_args = {
                             'vertical_flip': True,
                             'horizontal_flip': True
}
# apply same args for generator
image_datagen = ImageDataGenerator(**data_gen_args)

# set same seed number and apply it to X and Y (mask)
seed = 1
image_datagen.fit(x_train, augment=True, seed=seed)

train_gen = image_datagen.flow(x_train, y_train, seed=seed, batch_size=32, shuffle=True)

# train_gen = zip(image_generator, feature_generator,  mask_generator)
val_gen = (x_test, y_test)

# %%
train_util.train(model, train_gen, val_gen, steps_per_epoch=32, loss='categorical_crossentropy')

# %%
loaded_model = load_model('./log/2018_0728_1233/best_weights.hdf5')

# %%
preds_test = loaded_model.predict(x_test, verbose=1)
# Out:
# 389/389 [==============================] - 6s 16ms/step

# %%
preds_test
# Out:
# array([[0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [1.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [1.9500689e-17],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [2.5636387e-18],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [1.8971737e-03],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [1.9500689e-17],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [1.9500689e-17],
#        [1.9500689e-17],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [1.3152780e-37],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [1.9500689e-17],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [1.9500689e-17],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [4.1197317e-35],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [1.9500689e-17],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [1.9500689e-17],
#        [0.0000000e+00],
#        [2.5014184e-09],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [3.2686514e-01],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [9.9992943e-01],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [1.7609157e-30],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00]], dtype=float32)

# %%
import gc
del  dense_model
del  model
gc.collect()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-17-f0ca4e948b39> in <module>()
#       1 import gc
# ----> 2 del  dense_model
#       3 del  model
#       4 gc.collect()
#
# NameError: name 'dense_model' is not defined
