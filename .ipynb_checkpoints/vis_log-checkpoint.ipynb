# %% [markdown]
# # import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# %matplotlib inline
# import seaborn as sns
# from glob import glob

# %%
def show_log(dir_name, col=None):
    log_file_path = './log/' + dir_name + '/training.log'
    log = pd.read_csv(log_file_path)
    if col is not Non:
        log = log[col]
    log.plot(x='epoch')
    return log

# %%
log1 = show_log('2018_0729_1817')

# %%
np.min(log1.val_loss)
# Out:
# 0.1576288288831711

# %%
show_log('2018_0723_1717')

# %%
log2 = show_log('2018_0728_2026')
np.min(log2.val_loss)
# unet_256
# Out:
# 0.128431546743624

# %%
log3 = show_log('2018_0728_1659')
np.min(log3.val_loss)
# Out:
# 0.16008224118031694

# %%
log3 = show_log('2018_0727_2358')
np.min(log3.val_loss)
# Out:
# 0.07965438623354798

# %%
log3 = show_log('2018_0727_1808')
np.min(log3.val_loss)
# Out:
# 0.09741833055233894

# %%
log3 = show_log('2018_0729_0020')
np.min(log3.val_loss)
# Out:
# 0.1815815817152933

# %%
log.plot(x='epoch')
